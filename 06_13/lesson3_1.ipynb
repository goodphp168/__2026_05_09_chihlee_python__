# %%
import pandas as pd

df = pd.DataFrame({
    "學生姓名": ["王小明", "趙冠宇", "李小華", "趙冠宇"],
    "分數": [80, 95, 72, 88]
})

df[df["學生姓名"] == "趙冠宇"]
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# Name: 學生姓名, dtype: bool
